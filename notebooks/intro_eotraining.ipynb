# %% [markdown]
# # EOtraining - Trainings for EO data manipulation in Python

# %% [markdown]
# ### Travaux pratiques - INSA Strasbourg

# %% [markdown]
# [TP optionnel - Introduction à Python](tp_insa/01_introduction_generale_fr.ipynb)
#
# [TP - Manipulation de données raster en Python](tp_insa/02_intro_manipulation_images_fr.ipynb)
